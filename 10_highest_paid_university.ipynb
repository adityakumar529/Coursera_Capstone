# %%
import pandas as pd

# %%
data = pd.read_csv("E:/DS/csv.csv")

# %%
data.head()
# Out:
#                       University        Department Overall Pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science     $20,000      0.72
# 1                            USC               ECE     $32,000       NaN
# 2      New York University (NYU)    stern business     $36,500      1.23
# 3    University at Albany - SUNY       Psychology      $18,000      0.79
# 4   University of Virginia (UVA)           Spanish     $24,000      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay Fees  \
# 0     2020-2021          1st        $20,000           NaN           NaN  NaN
# 1     2020-2021          NaN        $32,000           NaN           NaN  NaN
# 2     2020-2021          1st        $36,500           NaN           NaN  NaN
# 3     2020-2021          1st            NaN       $18,000           NaN  NaN
# 4     2020-2021          NaN            NaN       $20,000        $4,000  NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
data.dtypes
# Out:
# University         object
# Department         object
# Overall Pay        object
# LW Ratio          float64
# Academic Year      object
# Program Year       object
# 12 M Gross Pay     object
# 9 M Gross Pay      object
# 3 M Gross Pay      object
# Fees               object
# Comments           object
# dtype: object

# %%
data = data.rename(columns={'Overall Pay': 'Overall_pay'})

# %%
data.head()
# Out:
#                       University        Department Overall_pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science     $20,000      0.72
# 1                            USC               ECE     $32,000       NaN
# 2      New York University (NYU)    stern business     $36,500      1.23
# 3    University at Albany - SUNY       Psychology      $18,000      0.79
# 4   University of Virginia (UVA)           Spanish     $24,000      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay Fees  \
# 0     2020-2021          1st        $20,000           NaN           NaN  NaN
# 1     2020-2021          NaN        $32,000           NaN           NaN  NaN
# 2     2020-2021          1st        $36,500           NaN           NaN  NaN
# 3     2020-2021          1st            NaN       $18,000           NaN  NaN
# 4     2020-2021          NaN            NaN       $20,000        $4,000  NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
data['Overall_pay'] = data['Overall_pay'].str.replace('$', '')

# %%
data.head()
# Out:
#                       University        Department Overall_pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science      20,000      0.72
# 1                            USC               ECE      32,000       NaN
# 2      New York University (NYU)    stern business      36,500      1.23
# 3    University at Albany - SUNY       Psychology       18,000      0.79
# 4   University of Virginia (UVA)           Spanish      24,000      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay Fees  \
# 0     2020-2021          1st        $20,000           NaN           NaN  NaN
# 1     2020-2021          NaN        $32,000           NaN           NaN  NaN
# 2     2020-2021          1st        $36,500           NaN           NaN  NaN
# 3     2020-2021          1st            NaN       $18,000           NaN  NaN
# 4     2020-2021          NaN            NaN       $20,000        $4,000  NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
data['12 M Gross Pay'] = data['12 M Gross Pay'].str.replace('$', '')

# %%
data['9 M Gross Pay'] = data['9 M Gross Pay'].str.replace('$', '')

# %%
data['3 M Gross Pay'] = data['3 M Gross Pay'].str.replace('$', '')

# %%
data.dtypes
# Out:
# University         object
# Department         object
# Overall_pay        object
# LW Ratio          float64
# Academic Year      object
# Program Year       object
# 12 M Gross Pay     object
# 9 M Gross Pay      object
# 3 M Gross Pay      object
# Fees               object
# Comments           object
# dtype: object

# %%
data.head()
# Out:
#                       University        Department Overall_pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science      20,000      0.72
# 1                            USC               ECE      32,000       NaN
# 2      New York University (NYU)    stern business      36,500      1.23
# 3    University at Albany - SUNY       Psychology       18,000      0.79
# 4   University of Virginia (UVA)           Spanish      24,000      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay Fees  \
# 0     2020-2021          1st         20,000           NaN           NaN  NaN
# 1     2020-2021          NaN         32,000           NaN           NaN  NaN
# 2     2020-2021          1st         36,500           NaN           NaN  NaN
# 3     2020-2021          1st            NaN        18,000           NaN  NaN
# 4     2020-2021          NaN            NaN        20,000         4,000  NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
data['Overall_pay'] = data['Overall_pay'].str.replace(',', '')

# %%
data.head()
# Out:
#                       University        Department Overall_pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science       20000      0.72
# 1                            USC               ECE       32000       NaN
# 2      New York University (NYU)    stern business       36500      1.23
# 3    University at Albany - SUNY       Psychology        18000      0.79
# 4   University of Virginia (UVA)           Spanish       24000      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay Fees  \
# 0     2020-2021          1st         20,000           NaN           NaN  NaN
# 1     2020-2021          NaN         32,000           NaN           NaN  NaN
# 2     2020-2021          1st         36,500           NaN           NaN  NaN
# 3     2020-2021          1st            NaN        18,000           NaN  NaN
# 4     2020-2021          NaN            NaN        20,000         4,000  NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
data['Overall_pay'] = data['Overall_pay'].astype(float)

# %%
data.head()
data.dropna(subset=['University'])
data.dropna(subset=['Department'])
# Out:
#                          University              Department  Overall_pay  \
# 0     Stony Brook University - SUNY        Computer Science      20000.0
# 1                               USC                     ECE      32000.0
# 2         New York University (NYU)          stern business      36500.0
# 3       University at Albany - SUNY             Psychology       18000.0
# 4      University of Virginia (UVA)                 Spanish      24000.0
# ...                             ...                     ...          ...
# 8358           Duke University (DU)            Biochemistry      29840.0
# 8359   University of Virginia (UVA)    Chemical Engineering      32000.0
# 8360           Duke University (DU)  Biomedical Engineering      32000.0
# 8361   University of Virginia (UVA)    Chemical Engineering      25000.0
# 8362           Duke University (DU)  Biomedical Engineering      27850.0
#
#       LW Ratio Academic Year Program Year 12 M Gross Pay 9 M Gross Pay  \
# 0         0.72     2020-2021          1st         20,000           NaN
# 1          NaN     2020-2021          NaN         32,000           NaN
# 2         1.23     2020-2021          1st         36,500           NaN
# 3         0.79     2020-2021          1st            NaN         18000
# 4         1.05     2020-2021          NaN            NaN         20000
# ...        ...           ...          ...            ...           ...
# 8358      1.59     2012-2013   6th and up         29,840           NaN
# 8359      1.63     2013-2014          4th         32,000           NaN
# 8360      1.70     2013-2014          2nd         32,000           NaN
# 8361      1.28     2013-2014          4th         25,000           NaN
# 8362      1.48     2013-2014   6th and up         27,850           NaN
#
#      3 M Gross Pay  Fees                                           Comments
# 0              NaN   NaN                                                NaN
# 1              NaN   NaN                                                NaN
# 2              NaN   NaN                     two year of discounted housing
# 3              NaN   NaN                                                NaN
# 4            4,000   NaN                                                NaN
# ...            ...   ...                                                ...
# 8358           NaN   NaN                                                NaN
# 8359           NaN   NaN  This includes health insurance coverage, tuiti...
# 8360           NaN   NaN  This is the stipend associated with the NSF Fe...
# 8361           NaN   NaN  This stipend includes full health insurance co...
# 8362           NaN   NaN  I just receive the base stipend in my departme...
#
# [7922 rows x 11 columns]

# %%
data['Overall_pay'].max()
# Out:
# 994000.0

# %%
data['Fees'] = data['Fees'].str.replace('$', '')
data['Fees'] = data['Fees'].str.replace(',', '')
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-429129583dfa> in <module>
# ----> 1 data['Fees'] = data['Fees'].str.replace('$', '')
#       2 data['Fees'] = data['Fees'].str.replace(',', '')
#       3 data.head()
#       4
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2037
#    2038     def __init__(self, data):
# -> 2039         self._inferred_dtype = self._validate(data)
#    2040         self._is_categorical = is_categorical_dtype(data)
#    2041         self._is_string = data.dtype.name == "string"
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2094
#    2095         if inferred_dtype not in allowed_types:
# -> 2096             raise AttributeError("Can only use .str accessor with string values!")
#    2097         return inferred_dtype
#    2098
#
# AttributeError: Can only use .str accessor with string values!

# %%
data.head(100)
# Out:
#                                   University                  Department  \
# 0              Stony Brook University - SUNY            Computer Science
# 1                                        USC                         ECE
# 2                  New York University (NYU)              stern business
# 3                University at Albany - SUNY                 Psychology
# 4               University of Virginia (UVA)                     Spanish
# ..                                       ...                         ...
# 95               University of Oklahoma (OU)  Data Science and Analytics
# 96                     CUNY - Hunter College                     Biology
# 97                     CUNY - Hunter College                     BIOLOGY
# 98               Texas Tech University (TTU)        Chemical Engineering
# 99  Louisiana State University - Baton Rouge        Chemical Engineering
#
#     Overall_pay  LW Ratio Academic Year Program Year 12 M Gross Pay  \
# 0       20000.0      0.72     2020-2021          1st         20,000
# 1       32000.0       NaN     2020-2021          NaN         32,000
# 2       36500.0      1.23     2020-2021          1st         36,500
# 3       18000.0      0.79     2020-2021          1st            NaN
# 4       24000.0      1.05     2020-2021          NaN            NaN
# ..          ...       ...           ...          ...            ...
# 95      19000.0      0.94     2020-2021          1st         24,000
# 96      29872.0      1.00     2018-2019          2nd         30,000
# 97      34757.0      1.17     2019-2020          3rd         34,885
# 98      24000.0      1.18     2020-2021          1st         29,000
# 99      25000.0      1.15     2020-2021          1st         25,000
#
#    9 M Gross Pay 3 M Gross Pay    Fees  \
# 0            NaN           NaN     NaN
# 1            NaN           NaN     NaN
# 2            NaN           NaN     NaN
# 3          18000           NaN     NaN
# 4          20000         4,000     NaN
# ..           ...           ...     ...
# 95           NaN           NaN  5000.0
# 96           NaN           NaN   128.0
# 97           NaN           NaN   128.0
# 98           NaN           NaN  5000.0
# 99           NaN           NaN     NaN
#
#                                              Comments
# 0                                                 NaN
# 1                                                 NaN
# 2                      two year of discounted housing
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  Heavy teaching burden.  1/2-2/3 of my salary c...
# 97  For 2019 tax year,  $23706 from TA,  $11179 fr...
# 98                    Out of pocket health insurance
# 99  $2800 University health insurance, ~$400 Manda...
#
# [100 rows x 11 columns]

# %%
#University with highest overall pay 
data[data['Overall_pay'] == data['Overall_pay'].max()]['University']
# Out:
# 2767    Illinois Institute of Technology (IIT)
# Name: University, dtype: object

# %%
#Depatment with highest overall pay 
data[data['Overall_pay'] == data['Overall_pay'].max()]['Department']
# Out:
# 2767    Finance
# Name: Department, dtype: object

# %%
data['Overall_pay'].nlargest(2)
# Out:
# 2767    994000.0
# 470     500000.0
# Name: Overall_pay, dtype: float64

# %%
data = data[data['Department'].notnull()]
data.head()
# Out:
#                       University        Department  Overall_pay  LW Ratio  \
# 0  Stony Brook University - SUNY  Computer Science      20000.0      0.72
# 1                            USC               ECE      32000.0       NaN
# 2      New York University (NYU)    stern business      36500.0      1.23
# 3    University at Albany - SUNY       Psychology       18000.0      0.79
# 4   University of Virginia (UVA)           Spanish      24000.0      1.05
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay  Fees  \
# 0     2020-2021          1st         20,000           NaN           NaN   NaN
# 1     2020-2021          NaN         32,000           NaN           NaN   NaN
# 2     2020-2021          1st         36,500           NaN           NaN   NaN
# 3     2020-2021          1st            NaN         18000           NaN   NaN
# 4     2020-2021          NaN            NaN         20000         4,000   NaN
#
#                          Comments
# 0                             NaN
# 1                             NaN
# 2  two year of discounted housing
# 3                             NaN
# 4                             NaN

# %%
#University with highest pay
high10_University = data.nlargest(10, "Overall_pay") 
print(high10_University.University)
# Out:
# 2767              Illinois Institute of Technology (IIT)
# 503                             Icahn School of Medicine
# 2726                             Harvard University (HU)
# 4713             University of Southern California (USC)
# 1134                                   Dartmouth College
# 3946                        Northwestern University (NU)
# 3375    University of North Carolina - Chapel Hill (UNC)
# 7028                        Northwestern University (NU)
# 5428       University of California - Los Angeles (UCLA)
# 1448                                   andhra university
# Name: University, dtype: object

# %%
#University with highest pay
high10_Department = data.nlargest(10, "Overall_pay").Department
print(high10_Department)
# Out:
# 2767                         Finance
# 503                     Neuroscience
# 2726                  medical school
# 4713             Biological sciences
# 1134    Thayer School of Engineering
# 3946                      statistics
# 3375                        Strategy
# 7028               Political Science
# 5428                computer science
# 1448                 instrumentation
# Name: Department, dtype: object
